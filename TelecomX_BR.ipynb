# %% [markdown]
# #📌 Extracão

# %%
import pandas as pd

# %%
# Carrega dados JSON
df = pd.read_json('TelecomX_Data.json')
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
customer_normalizado = pd.json_normalize(df['customer'])
customer_normalizado
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
phone_normalizado = pd.json_normalize(df['phone'])
phone_normalizado
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
internet_normalizado = pd.json_normalize(df['internet'])
internet_normalizado
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
account_normalizado = pd.json_normalize(df['account'])
account_normalizado
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
# Unifica as vaariáveis em um dataframe
df = pd.concat([df[['customerID','Churn']], customer_normalizado, phone_normalizado, internet_normalizado, account_normalizado], axis=1)
df
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %% [markdown]
# #🔧 Transformação

# %%
(df == '').sum()
# Out:
# customerID            0
# Churn               224
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# Charges.Monthly       0
# Charges.Total         0
# dtype: int64

# %%
# Substituindo os espaços em branco por NaN
df['Charges.Total'] = df['Charges.Total'].replace(' ', pd.NA)
df['Churn'] = df['Churn'].replace('', pd.NA)

# %%
# Converte para numérica a coluna Charges.Total
df['Charges.Total'] = pd.to_numeric(df['Charges.Total'], errors='coerce')

# %%
df[(df['StreamingMovies'] != 'Yes') & (df['StreamingMovies'] != 'No')]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    0023-UYUPN    No  Female              1     Yes         No      50
# 23    0030-FNXPP    No  Female              0      No         No       3
# 24    0031-PVLZI   Yes  Female              0     Yes        Yes       4
# 27    0040-HALCW    No    Male              0     Yes        Yes      54
# 28    0042-JVWOJ    No    Male              0      No         No      26
# ...          ...   ...     ...            ...     ...        ...     ...
# 7250  9970-QBCDA    No  Female              0      No         No       6
# 7252  9972-EWRJS    No  Female              0     Yes        Yes      67
# 7256  9975-GPKZU    No    Male              0     Yes        Yes      46
# 7257  9975-SKRNR    No    Male              0      No         No       1
# 7261  9986-BONCE   Yes  Female              0      No         No       4
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
# Converte para bool
colunas_binarias = ['SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                    'StreamingTV', 'StreamingMovies', 'PaperlessBilling']

for coluna in colunas_binarias:
    df[coluna] = df[coluna].replace({'Yes': True, 'No': False, 0: False, 1: True, 'No phone service': False, 'No internet service': False})
# Out:
# /tmp/ipython-input-2848421738.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[coluna] = df[coluna].replace({'Yes': True, 'No': False, 0: False, 1: True, 'No phone service': False, 'No internet service': False})

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   bool
#  4   Partner           7267 non-null   bool
#  5   Dependents        7267 non-null   bool
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   bool
#  8   MultipleLines     7267 non-null   bool
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   bool
#  11  OnlineBackup      7267 non-null   bool
#  12  DeviceProtection  7267 non-null   bool
#  13  TechSupport       7267 non-null   bool
#  14  StreamingTV       7267 non-null   bool
#  15  StreamingMovies   7267 non-null   bool
#  16  Contract          7267 non-null   object
# ...

# %%
# Removendo as linhas que contêm NaN
df.dropna(inplace=True)

# Remove colunas relevantes para a análise de evasão
df.drop(columns=['customerID'], inplace=True)

# %%
# Converte a coluna target para bool
df['Churn'] = df['Churn'].replace({'Yes': True, 'No': False})
# Out:
# /tmp/ipython-input-1843449570.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Churn'] = df['Churn'].replace({'Yes': True, 'No': False})

# %%
# Criando a coluna Contas_Diarias que proporciona uma visão mais detalhada do comportamento dos clientes ao longo do tempo
df['Contas_Diarias'] = df['Charges.Monthly'] / df['tenure']
df
# Out:
#       Churn  gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0     False  Female          False     True        True       9          True
# 1     False    Male          False    False       False       9          True
# 2      True    Male          False    False       False       4          True
# 3      True    Male           True     True       False      13          True
# 4      True  Female           True     True       False       3          True
# ...     ...     ...            ...      ...         ...     ...           ...
# 7262  False  Female          False    False       False      13          True
# 7263   True    Male          False     True       False      22          True
# 7264  False    Male          False    False       False       2          True
# 7265  False    Male          False     True        True      67          True
# 7266  False    Male          False     True        True      63         False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7032 non-null   bool
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   bool
#  3   Partner           7032 non-null   bool
#  4   Dependents        7032 non-null   bool
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   bool
#  7   MultipleLines     7032 non-null   bool
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   bool
#  10  OnlineBackup      7032 non-null   bool
#  11  DeviceProtection  7032 non-null   bool
#  12  TechSupport       7032 non-null   bool
#  13  StreamingTV       7032 non-null   bool
#  14  StreamingMovies   7032 non-null   bool
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   bool
# ...

# %% [markdown]
# #📊 Carga e análise

# %%
# Análise descritiva
df.describe()
# Out:
#             tenure  Charges.Monthly  Charges.Total  Contas_Diarias
# count  7032.000000      7032.000000    7032.000000     7032.000000
# mean     32.421786        64.798208    2283.300441        8.620087
# std      24.545260        30.085974    2266.771362       16.352057
# min       1.000000        18.250000      18.800000        0.268056
# 25%       9.000000        35.587500     401.450000        1.277708
# 50%      29.000000        70.350000    1397.475000        2.147286
# 75%      55.000000        89.862500    3794.737500        6.611218
# max      72.000000       118.750000    8684.800000      102.450000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Contagem de clientes que saíram (True) e permaneceram (False)
churn_counts = df['Churn'].value_counts()

# Mapeando os rótulos
labels = ['Permanece na empresa', 'Saiu da empresa']
churn_counts.index = labels

# Definindo as cores
cores = ['olive', 'brown']

# Criando a figura
fig, ax = plt.subplots(figsize=(10, 8))

# Criando o gráfico de barras a partir das contagens
ax.bar(churn_counts.index, churn_counts.values, color=cores)

# Personalizando o gráfico
ax.set_title('Distribuição da Evasão de Clientes', loc='left', fontsize=18)
ax.set_ylabel('Qtde. de Clientes', fontsize=14)
ax.set_xlabel('')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12, rotation=0)

# Adicionando rótulos com a quantidade de clientes
for i, value in enumerate(churn_counts.values):
    ax.text(i, value + 50, str(value), ha='center', va='bottom', fontsize=12)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Contagem de evasão por variáveis categóricas

# %%
# Por gênero
# Contagem de clientes por gênero que saíram (True) e permaneceram (False)
churn_gender = df.groupby('gender')['Churn'].value_counts().unstack()

# Criando a figura
fig, ax = plt.subplots(figsize=(8, 8))

# Plotando as barras
churn_gender.plot(kind='bar', ax=ax, rot=0, color=['olive', 'brown'])

# Personalizando o gráfico
ax.set_title('Evasão de Clientes por Gênero', loc='left', fontsize=18)
ax.set_xlabel('Gênero', fontsize=14)
ax.set_ylabel('Qtde. de Clientes', fontsize=14)

# Ajustando a legenda
ax.legend(['Permaneceu', 'Saiu'], title='Status de Churn')

# Adicionando rótulos de valores em cada barra
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12)

# Exibindo o gráfico
plt.show()

# %%
# Por tipo de contrato
# Contagem de clientes por contrato que saíram (True) e permaneceram (False)
churn_contract = df.groupby('Contract')['Churn'].value_counts().unstack()

# Criando a figura
fig, ax = plt.subplots(figsize=(8, 8))

# Plotando as barras
churn_contract.plot(kind='bar', ax=ax, rot=0, color=['olive', 'brown'])

# Personalizando o gráfico
ax.set_title('Evasão de Clientes por Tipo de Contrato', loc='left', fontsize=18)
ax.set_xlabel('Tipo de Contrato', fontsize=14)
ax.set_ylabel('Qtde. de Clientes', fontsize=14)

# Ajustando a legenda
ax.legend(['Permaneceu', 'Saiu'], title='Status de Churn')

# Adicionando rótulos de valores em cada barra
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12)

# Exibindo o gráfico
plt.show()

# %%
# Por método de pagamento
# Contagem de clientes por método de pagamento que saíram (True) e permaneceram (False)
churn_payment = df.groupby('PaymentMethod')['Churn'].value_counts().unstack()

# Criando a figura
fig, ax = plt.subplots(figsize=(12, 8))

# Plotando as barras
churn_payment.plot(kind='barh', ax=ax, rot=0, color=['olive', 'brown'])

# Personalizando o gráfico
ax.set_title('Evasão de Clientes por Método de Pagamento', loc='left', fontsize=18)
ax.set_ylabel('Método de Pagamento', fontsize=14)
ax.set_xlabel('Qtde. de Clientes', fontsize=14)

# Ajustando a legenda
ax.legend(['Permaneceu', 'Saiu'], title='Status de Churn')

# Adicionando rótulos de valores em cada barra
for p in ax.patches:
    # A posição x (horizontal) é a largura da barra
    x_val = p.get_width()
    # A posição y (vertical) é o centro da barra
    y_val = p.get_y() + p.get_height() / 2
    # Anotar o valor da largura na posição correta
    ax.annotate(f'{int(x_val)}', (x_val, y_val), va='center', xytext=(5, 0), textcoords='offset points')


# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Contagem de evasão por variáveis numéricas

# %%
# Separando os dados em dois grupos: clientes que ficaram e clientes que saíram
tenure_churn_no = df[df['Churn'] == False]['tenure']
tenure_churn_yes = df[df['Churn'] == True]['tenure']

# Criando a figura
fig, ax = plt.subplots(figsize=(12, 6))

# Plotando o histograma para 'tenure'
ax.hist(tenure_churn_no, bins=30, alpha=0.6, color='olive', label='Não Evadiu')
ax.hist(tenure_churn_yes, bins=30, alpha=0.6, color='brown', label='Evadiu')
ax.set_title('Distribuição de Meses de Contrato', fontsize=16)
ax.set_xlabel('Meses de Contrato', fontsize=12)
ax.set_ylabel('Qtde. de Clientes', fontsize=12)
ax.legend()

# Exibindo o gráfico
plt.show()

# %%
# Separando os dados em dois grupos: clientes que ficaram e clientes que saíram
charges_churn_no = df[df['Churn'] == False]['Charges.Total']
charges_churn_yes = df[df['Churn'] == True]['Charges.Total']

# Criando a figura
fig, ax = plt.subplots(figsize=(12, 6))

# Plotando o histograma para 'Charges.Total'
ax.hist(charges_churn_no, bins=30, alpha=0.6, color='olive', label='Não Evadiu')
ax.hist(charges_churn_yes, bins=30, alpha=0.6, color='brown', label='Evadiu')
ax.set_title('Distribuição de Gasto Total', fontsize=16)
ax.set_xlabel('Gasto Total', fontsize=12)
ax.set_ylabel('Qtde. de Clientes', fontsize=12)
ax.legend()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# #📄Relatorio Final
# ##📌 Introdução
# Este relatório detalha a análise exploratória de dados (AED) conduzida para o projeto "Churn de Clientes" da **Telecom X**. O objetivo principal é identificar os fatores que levam os clientes a cancelar seus serviços. Compreender esses fatores é essencial para que a equipe de Data Science possa desenvolver estratégias eficazes de retenção de clientes.
# ##🧹 Limpeza e Tratamento de Dados
# A fase de pré-processamento dos dados foi crucial para garantir a qualidade e a consistência para a análise. Os passos realizados foram:
# 1. **Extração e Unificação de Dados:** Os dados foram carregados de um arquivo JSON. As informações de `customer`, `phone`, `internet` e `account` foram normalizadas e unificadas com as colunas `customerID` e `Churn` em um único DataFrame.
# 2. **Tratamento de Valores Ausentes e Inconsistentes:**
# - Valores em branco (`' '`) na coluna `Charges.Total` foram substituídos por `NaN` (Not a Number) e, em seguida, convertidos para o tipo numérico (`float`) utilizando `pd.to_numeric` com `errors='coerce'` para lidar com quaisquer outros valores não numéricos.
# - Valores em branco na coluna `Churn` foram tratados como `NaN`.
# - Linhas contendo quaisquer valores `NaN` foram removidas do DataFrame para garantir a integridade da análise.
# 3. **Conversão de Tipos de Dados:**
# - A coluna `Churn` (variável alvo) foi convertida para o tipo booleano (`True` para 'Yes' e `False` para 'No').
# - Múltiplas colunas binárias (`SeniorCitizen`, `Partner`, `Dependents`, `PhoneService`, `MultipleLines`, `OnlineSecurity`, `OnlineBackup`, `DeviceProtection`, `TechSupport`, `StreamingTV`, `StreamingMovies`, `PaperlessBilling`) foram convertidas para o tipo booleano (`True`/`False`). Foi realizado um mapeamento abrangente para incluir 'Yes', 'No', 0, 1, 'No phone service' e 'No internet service', garantindo que todas as variações fossem corretamente interpretadas como `True` ou `False`.
# 4. **Engenharia de Features:** Uma nova coluna, `Contas_Diarias`, foi criada dividindo `Charges.Monthly` por `tenure`. Embora calculada, a análise exploratória focou nas variáveis originais (`Charges.Monthly` e `tenure`) para insights mais diretos.
# 5. **Remoção de Colunas:** A coluna `customerID` foi removida, pois é um identificador único e não contribui para a análise de padrões de churn.
#
# ##📊 Análise Exploratória de Dados
# A análise exploratória de dados (AED) foi realizada através de visualizações gráficas para identificar padrões e relações entre as variáveis e o status de churn.
#
# **Distribuição Geral do Churn**
#
# A análise inicial focou na proporção de clientes que cancelaram seus serviços em relação aos que permaneceram.
#
# **Gráfico 1: Distribuição da Evasão de Clientes**
#
# - **Insight:** O gráfico revela a proporção de clientes que evadiram, destacando a magnitude do problema de churn na Telecom X. Pode-se ver que 5163 clientes permanecem na empresa e 1869 saíram.
#
# **Evasão por Variáveis Categóricas**
#
# Foram investigadas as relações entre o churn e variáveis categóricas como gênero, tipo de contrato e método de pagamento.
#
# **Gráfico 2: Evasão de Clientes por Gênero**
#
# - **Insight:** A análise por gênero indica que não há uma diferença significativa na taxa de evasão entre clientes masculinos e femininos, sugerindo que o gênero não é um fator primário de churn.
#
# **Gráfico 3: Evasão de Clientes por Tipo de Contrato**
#
# - **Insight:** Clientes com contratos mensais (`Month-to-month`) apresentam uma taxa de churn mais alta em comparação com aqueles que possuem contratos de um ou dois anos. Isso sugere que a fidelidade do cliente está fortemente ligada à duração do contrato.
#
# **Gráfico 4: Evasão de Clientes por Método de Pagamento**
#
# - **Insight:** O método de pagamento `Electronic check` está associado à maior taxa de churn (1071 clientes). Clientes que utilizam métodos de pagamento automáticos, como `Bank transfer (automatic)` e `Credit card (automatic)`, demonstram menor propensão à evasão.
#
# **Evasão por Variáveis Numéricas**
#
# A distribuição de variáveis numéricas como meses de contrato (`tenure`) e gasto total (`Charges.Total`) foi examinada para identificar padrões entre clientes que evadiram e os que não evadiram.
#
# **Gráfico 5: Distribuição de Meses de Contrato (Tenure)**
#
# - **Insight:** Há uma concentração de clientes que evadem nos primeiros meses de contrato (`tenure` baixo), indicando que a insatisfação ou a decisão de cancelar ocorre frequentemente logo no início da jornada do cliente.
#
# **Gráfico 6: Distribuição de Gasto Total (Charges.Total)**
#
# - **Insight:** Clientes com um gasto total (`Charges.Total)` menor são mais propensos a cancelar seus serviços. Isso pode indicar que clientes que utilizam menos serviços ou têm contas de menor valor são mais suscetíveis ao churn.
#
# ##✅ Conclusões e Recomendações
#
# **Conclusões Principais**
#
# - **Contrato e Pagamento são Chaves:** O tipo de contrato (`Month-to-month`) e o método de pagamento (`Electronic check`) são os indicadores mais fortes de churn.
# - **Churn Precoce:** A maioria dos cancelamentos ocorre nos primeiros meses de contrato (`tenure` baixo).
# - **Gasto Total:** Clientes com menor gasto total são mais propensos a evadir.
# - **Gênero Irrelevante:** O gênero não demonstrou ser um fator significativo na decisão de churn.
#
# **Recomendações Estratégicas**
#
# Com base nesta análise, são propostas as seguintes recomendações:
# 1. **Programas de Boas-Vindas e Suporte Intensivo:** Focar em um programa robusto de integração e suporte proativo para novos clientes, especialmente nos primeiros 6 meses, para mitigar o churn precoce.
# 2. **Incentivos para Contratos Mais Longos:** Desenvolver campanhas e ofertas especiais para encorajar clientes de contratos mensais a migrarem para planos anuais ou bienais, aumentando a fidelidade.
# 3. **Otimização do Método de Pagamento:** Investigar as razões por trás da alta taxa de churn associada ao `Electronic check`. Isso pode envolver a melhoria da experiência de pagamento, oferecendo alternativas mais convenientes ou incentivando a mudança para pagamentos automáticos.
# 4. **Segmentação e Ofertas Personalizadas:** Utilizar os insights sobre `tenure` e `Charges.Total` para segmentar clientes de baixo gasto ou com pouco tempo de contrato, oferecendo pacotes de serviços mais adequados ou promoções para aumentar o engajamento e o valor percebido.
# 5. **Próximos Passos para Modelagem Preditiva:** A equipe de Data Science pode avançar para a construção de modelos preditivos, utilizando as variáveis identificadas como relevantes nesta AED para prever quais clientes estão em risco de churn e permitir intervenções proativas.
